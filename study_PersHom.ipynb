# %%
from persim import plot_diagrams
from ripser import ripser
from src.PHomClass import PhomPCA

# %%
from src.ShapeClass import Torus

data = Torus(500).generate_data()

pers = PhomPCA(data)
pers.embedding(20, noise=True)
pers.reconstruction(kernel=True)
pers.compute_pers_diag()
pers.plot(save=True, title=True)

# %%
from src.ShapeClass import Torus

data = Torus(500).generate_data()

pers = PhomPCA(data)
pers.embedding(20, noise=False)
pers.reconstruction(kernel=True)
pers.compute_pers_diag()
pers.plot(save=True, title=True)

# %%
from src.ShapeClass import Sphere

data = Sphere(300).generate_data()

pers = PhomPCA(data)
pers.embedding(20, noise=True)
pers.reconstruction(kernel=True)
pers.compute_pers_diag()
pers.plot(save=True, title=True)

# %%
from src.ShapeClass import Eight

data = Eight(n=500).generate_data()

pers = PhomPCA(data)
pers.embedding(20, noise=True)
pers.reconstruction(kernel=True)
pers.compute_pers_diag()
pers.plot(save=True, title=True)

# %%
from src.ShapeClass import Eight

data = Eight(n=500).generate_data()

pers = PhomPCA(data)
pers.embedding(20, noise=False)
pers.reconstruction(kernel=True)
pers.compute_pers_diag()
pers.plot(save=True, title=True)

# %%
# generate some 2D data
from src.ShapeClass import Circle

data = Circle(n=200).generate_data()

pers = PhomPCA(data)
pers.embedding(20, noise=True)
pers.reconstruction(kernel=True)
pers.compute_pers_diag()
pers.plot(save=True, title=True)
