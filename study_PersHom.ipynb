# %%
import matplotlib.pyplot as plt
import numpy as np
from persim import plot_diagrams
from sklearn.decomposition import PCA
from ripser import ripser
from src.PHomClass import PhomPCA

# %%
from src.shapes import torus

data = torus(400)

pers = PhomPCA(data)
pers.embedding(1, noise=False)
pers.reconstruction(kernel=True)
pers.compute_pers_diag()
pers.plot(save=True, title=True)

# %%
from src.shapes import sphere

data = sphere(300)

pers = PhomPCA(data)
pers.embedding(20)
pers.reconstruction()
pers.compute_pers_diag()
pers.plot()

# %%
from src.shapes import cylinder

data = cylinder(300)

pers = PhomPCA(data)
pers.embedding(20, noise=False)
pers.reconstruction()
pers.compute_pers_diag()
pers.plot()

# %%
# generate some 2D data
from src.shapes import eight

data = eight(n=200)
# plt.scatter(data[:, 0], data[:, 1])

pers = PhomPCA(data)
pers.embedding(20, noise=True)
pers.reconstruction(kernel=True)
pers.compute_pers_diag()
pers.plot(save=True, title=True)

# %%
# generate some 2D data
from src.shapes import circle

data = circle(n=200)
# plt.scatter(data[:, 0], data[:, 1])

pers = PhomPCA(data)
pers.embedding(20, noise=True)
pers.reconstruction(kernel=True)
pers.compute_pers_diag()
pers.plot()
